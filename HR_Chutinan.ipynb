# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import warnings


data = pd.read_csv('/Users/chutinan/Documents/Maching Learning/Dataset/HR.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d1b52bd53556> in <module>()
#       8
#       9
# ---> 10 data = pd.read_csv('/Users/chutinan/Documents/Maching Learning/Dataset/HR.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.56             0.89               4                   263
# 1                0.91             0.94               5                   159
# 2                0.36             0.95               6                   276
# 3                0.56             0.59               4                   164
# 4                0.77             0.73               3                   201
#
#    time_spend_company  Work_accident  left  promotion_last_5years  department  \
# 0                   3              0     0                      0  accounting
# 1                   3              0     0                      0   technical
# 2                   2              0     0                      0     support
# 3                   3              0     0                      1     support
# 4                  10              0     0                      0  management
#
#    salary
# 0     low
# 1     low
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12999 entries, 0 to 12998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     12999 non-null  float64
#  1   last_evaluation        12999 non-null  float64
#  2   number_project         12999 non-null  int64
#  3   average_montly_hours   12999 non-null  int64
#  4   time_spend_company     12999 non-null  int64
#  5   Work_accident          12999 non-null  int64
#  6   left                   12999 non-null  int64
#  7   promotion_last_5years  12999 non-null  int64
#  8   department             12999 non-null  object
#  9   salary                 12999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1015.7+ KB

# %%
data.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count           12,999.00        12,999.00       12,999.00
# mean                 0.61             0.72            3.80
# std                  0.25             0.17            1.24
# min                  0.09             0.36            2.00
# 25%                  0.44             0.56            3.00
# 50%                  0.64             0.72            4.00
# 75%                  0.81             0.87            5.00
# max                  1.00             1.00            7.00
#
#        average_montly_hours  time_spend_company  Work_accident      left  \
# count             12,999.00           12,999.00      12,999.00 12,999.00
# mean                 200.80                3.49           0.14      0.24
# std                   50.05                1.45           0.35      0.43
# min                   96.00                2.00           0.00      0.00
# ...

# %%
data['department'].value_counts()
# Out:
# sales          3593
# technical      2363
# support        1937
# IT             1062
# product_mng     790
# marketing       729
# RandD           674
# accounting      662
# hr              625
# management      564
# Name: department, dtype: int64

# %% [raw]
# # Data Visualization
#
#     After graphing the features in a pair plot, it is clear that the relationship between pairs of features of a iris-setosa (in pink) is distinctly different from those of the other two species.
# There is some overlap in the pairwise relationships of the other two species, iris-versicolor (brown) and iris-virginica (green).

# %%
import numpy as np

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data.corr()
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level                   1.00             0.10           -0.14
# last_evaluation                      0.10             1.00            0.35
# number_project                      -0.14             0.35            1.00
# average_montly_hours                -0.02             0.34            0.42
# time_spend_company                  -0.11             0.13            0.20
# Work_accident                        0.06            -0.01           -0.01
# left                                -0.39             0.01            0.02
# promotion_last_5years                0.02            -0.01           -0.01
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                    -0.02               -0.11
# last_evaluation                        0.34                0.13
# number_project                         0.42                0.20
# ...

# %%
sns.heatmap(data.corr()[['left']], annot=True, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data.corr());

# %%
data.hist(figsize=(11, 9))
plt.tight_layout()

# %%
import sklearn
X = sklearn.preprocessing.StandardScaler().fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-3712039d2e48> in <module>()
#       1 import sklearn
# ----> 2 X = sklearn.preprocessing.StandardScaler().fit_transform(X)
#       3
#
# AttributeError: module 'sklearn' has no attribute 'preprocessing'

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import warnings


data = pd.read_csv('/Users/chutinan/Documents/Maching Learning/Dataset/HR.csv')

# %%
ss = StandardScaler()
scale_features = ['average_monthly_hours', 'number_project', 'time_spend_company']
data[scale_features] = ss.fit_transform(data[scale_features])
